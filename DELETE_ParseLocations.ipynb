# %%
import pandas as pd

# %%
#dfs = {}
#for i in range(1, 11): 
#    file = "locations"+str(i)+".csv"
#    dfs["df_"+str(i)] = pd.read_csv(file)

# %%
#dfs

# %%
#locations = pd.concat(dfs.values(), ignore_index=True)

# %%
#locations.dtypes

# %%
#locations[locations['phone_number'] == 2018159770][['time_stamp','latitude','longitude','accuracy']]

# %%
locations = pd.read_csv("alllocations_limited.csv")
locations
# Out:
#          phone_number          ts   latitude  longitude  accuracy
# 0          2018159770  1534912144  41.703319 -86.233138        65
# 1          2018159770  1534912324  41.703275 -86.233146        30
# 2          2018159770  1534912504  41.703309 -86.233198        65
# 3          2018159770  1534912684  41.703309 -86.233198        65
# 4          2018159770  1534912864  41.703320 -86.233138        65
# ...               ...         ...        ...        ...       ...
# 2839287    9897454601  1541472569  41.699708 -86.240587        50
# 2839288    9897454601  1541472750  41.699708 -86.240587        50
# 2839289    9897454601  1541472936  41.699708 -86.240587        50
# 2839290    9897454601  1541473118  41.699708 -86.240587        50
# 2839291    9897454601  1541473298  41.699708 -86.240587        50
#
# [2839292 rows x 5 columns]

# %%
for number in locations.phone_number.unique():
    df = locations[locations['phone_number'] == number][['ts','latitude','longitude','accuracy']]
    file_name = str(number)+".csv"
    df.to_csv(file_name, index=False)

# %%
print('[')
for number in locations.phone_number.unique():
    print("\'"+str(number)+"\'"+", ")
print(']')
# Out:
# [
# '2018159770',
# '2025315435',
# '2034175085',
# '2059368116',
# '2062287154',
# '2069200835',
# '2077103848',
# '2109099146',
# '2135007406',
# '2149062229',
# '2174146944',
# '2196707494',
# '2244567371',
# '2245204125',
# '2245450936',
# '2246223748',
# '2316338219',
# '2482287091',
# '2488408508',
# '2514471719',
# '2537321828',
# '2622253434',
# '2623390135',
# '2623702227',
# '2623887068',
# '2625275069',
# '2816101590',
# '2819893149',
# '3017855377',
# '3057889674',
# '3108747665',
# '3125764026',
# '3128601235',
# '3139693954',
# '3144970665',
# '3145463889',
# '3145875800',
# '3146044161',
# '3155659083',
# '3173713758',
# '3176966365',
# '3177028408',
# '3177306827',
# '3179872245',
# '3303296748',
# '3303487454',
# '3365291279',
# '3377181990',
# '3476070384',
# '4014745533',
# '4022194581',
# '4029160883',
# '4047695323',
# '4073251013',
# '4073420212',
# '4074433276',
# '4075067111',
# '4087479586',
# '4124787938',
# '4194108635',
# '4235981050',
# '4407734331',
# ...
